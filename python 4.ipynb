# %%
data = {
    'Customer': ['Alice Johnson1', 'Bob2 Smith', 'Charlie3 Brown', 'Diana White4', 'Edward Clark5',
                 'Fiona6 Adams', 'George7 Wilson', 'Helen8 Green', 'Ian Thomas9', 'Jack Black10',
                 'Alice Johnson1', 'Bob2 Smith', None, 'Diana White4', 'Edward Clark5',
                 'Fiona6 Adams', 'George7 Wilson', 'Helen8 Green', None, 'Jack Black10',
                 'Karen White11', 'Liam Davis12', 'Mia13 Evans', 'Nathan14 King', 'Olivia Scott15'],
    
    'Phone_Number': ['+1-202-555-0101', '+44-20-7946-0234', '+1-202-555-0345', '+49-30-1234500', '+91-98765-40010',
                     '+1-202-555-0456', '+44-20-7946-0567', '+1-202-555-0678', '+49-30-9876500', '+91-98765-50021',
                     '+1-202-555-0101', '+44-20-7946-0234', None, '+49-30-1234500', '+91-98765-40010',
                     '+1-202-555-0456', '+44-20-7946-0567', None, '+49-30-9876500', None,
                     '+1-202-555-0789', '+44-20-7946-0890', '+1-202-555-0901', '+49-30-1357200', '+91-98765-60030'],
    
    'Address': ['USA, New York, 123 Main St, 10001', 'UK, London, 45 King St, W1B 4DY', 
                'USA, Chicago, 789 Oak Ave, 60611', 'Germany, Berlin, 12 Hauptstr, 10115', 
                'India, Mumbai, 56 Marine Dr, 400001', 'USA, San Francisco, 34 Bay St, 94105',
                'UK, Manchester, 22 Queen St, M2 5PD', None, 'USA, Austin, 89 River Rd, 73301', 
                'USA, Seattle, 78 Pine St, 98101', 'USA, New York, 123 Main St, 10001', 
                'UK, London, 45 King St, W1B 4DY', None, 'Germany, Berlin, 12 Hauptstr, 10115', 
                'India, Mumbai, 56 Marine Dr, 400001', 'USA, San Francisco, 34 Bay St, 94105',
                'UK, Manchester, 22 Queen St, M2 5PD', None, 'USA, Austin, 89 River Rd, 73301', 
                'USA, Seattle, 78 Pine St, 98101', 'USA, Boston, 10 Elm St, 02108', 
                'USA, Miami, 88 Ocean Dr, 33139', 'USA, Atlanta, 77 Peach St, 30303', 
                'USA, Denver, 99 Rocky Rd, 80202', 'USA, Orlando, 66 Magic St, 32830'],
    
    'Order_ID': [1001, 1002, None, 1004, 1005, 1006, None, 1008, 1009, 1010,
                 1001, 1002, None, 1004, 1005, 1006, None, 1008, None, 1010,
                 1011, 1012, 1013, None, 1015],
    
    'Order_Date': ['2023-06-15', '2023-07-21', '2023-08-10', '2023-09-05', '2023-10-30',
                   '2023-06-17', '2023-11-11', None, '2023-12-13', '2024-01-08',
                   '2023-06-15', '2023-07-21', None, '2023-09-05', '2023-10-30',
                   '2023-06-17', '2023-11-11', None, '2023-12-13', '2024-01-08',
                   '2024-02-20', '2024-03-22', '2024-04-30', '2024-05-17', '2024-06-29'],
    
    'Order_Price': [200.00, 110.00, None, 75.00, 300.00, 180.00, None, 150.00, 450.00, 480.00,
                    200.00, 110.00, None, 75.00, 300.00, 180.00, None, 150.00, None, 480.00,
                    175.00, 250.00, 135.00, None, 280.00],

    'Factory_Cost': [120.00, 80.00, None, 50.00, 200.00, 140.00, None, 100.00, 350.00, 400.00,
                     120.00, 80.00, None, 50.00, 200.00, 140.00, None, 100.00, None, 400.00,
                     130.00, 190.00, 100.00, None, 210.00],
    
    'Tax': [20.00, 10.50, None, 7.50, 30.00, 18.00, None, 15.00, 45.00, 48.00,
            20.00, 10.50, None, 7.50, 30.00, 18.00, None, 15.00, None, 48.00,
            17.50, 25.00, 13.50, None, 28.00],
    
    'Shipping_Amount': [15.00, 12.00, None, 10.00, 20.00, 15.00, None, 12.00, 25.00, 30.00,
                        15.00, 12.00, None, 10.00, 20.00, 15.00, None, 12.00, None, 30.00,
                        14.00, 18.00, 11.00, None, 22.00],
    
    'Shipping_Date': ['2023-06-18', '2023-07-23', '2023-08-12', '2023-09-08', '2023-11-01',
                      '2023-06-20', '2023-11-13', None, '2023-12-16', '2024-01-10',
                      '2023-06-18', '2023-07-23', None, '2023-09-08', '2023-11-01',
                      '2023-06-20', '2023-11-13', None, '2023-12-16', '2024-01-10',
                      '2024-02-23', '2024-03-25', '2024-05-03', '2024-05-20', '2024-06-30'],
    
    'Payment_Method': ['Credit Card', 'PayPal', 'Bank Transfer', 'Cash on Delivery', 'Credit Card',
                       'PayPal', 'Bank Transfer', None, 'Credit Card', 'Debit Card',
                       'Credit Card', 'PayPal', None, 'Cash on Delivery', 'Credit Card',
                       'PayPal', 'Bank Transfer', None, 'Credit Card', 'Debit Card',
                       'Apple Pay', 'Google Pay', 'Cryptocurrency', None, 'Credit Card'],
    
    'Customer_Type': ['Returning', 'New', 'New', 'Returning', 'New',
                      'Returning', 'New', None, 'Returning', 'New',
                      'Returning', 'New', None, 'Returning', 'New',
                      'Returning', 'New', None, 'Returning', 'New',
                      'New', 'Returning', 'New', None, 'Returning'],
    
    'Order_Status': ['Shipped', 'Pending', 'Canceled', 'Delivered', 'Shipped',
                     'Processing', 'Delivered', None, 'Shipped', 'Pending',
                     'Shipped', 'Pending', None, 'Delivered', 'Shipped',
                     'Processing', 'Delivered', None, 'Shipped', 'Pending',
                     'Canceled', 'Delivered', 'Shipped', None, 'Processing'],
    
    'Discount_Amount': [10.00, 5.00, None, 0.00, 15.00, 8.00, None, 12.00, 20.00, 25.00,
                        10.00, 5.00, None, 0.00, 15.00, 8.00, None, 12.00, None, 25.00,
                        7.00, 10.00, 6.00, None, 12.00]
}

# %%
import pandas as pd

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#           Customer      Phone_Number                               Address  \
# 0   Alice Johnson1   +1-202-555-0101     USA, New York, 123 Main St, 10001
# 1       Bob2 Smith  +44-20-7946-0234       UK, London, 45 King St, W1B 4DY
# 2   Charlie3 Brown   +1-202-555-0345      USA, Chicago, 789 Oak Ave, 60611
# 3     Diana White4    +49-30-1234500   Germany, Berlin, 12 Hauptstr, 10115
# 4    Edward Clark5   +91-98765-40010   India, Mumbai, 56 Marine Dr, 400001
# 5     Fiona6 Adams   +1-202-555-0456  USA, San Francisco, 34 Bay St, 94105
# 6   George7 Wilson  +44-20-7946-0567   UK, Manchester, 22 Queen St, M2 5PD
# 7     Helen8 Green   +1-202-555-0678                                  None
# 8      Ian Thomas9    +49-30-9876500       USA, Austin, 89 River Rd, 73301
# 9     Jack Black10   +91-98765-50021       USA, Seattle, 78 Pine St, 98101
# 10  Alice Johnson1   +1-202-555-0101     USA, New York, 123 Main St, 10001
# 11      Bob2 Smith  +44-20-7946-0234       UK, London, 45 King St, W1B 4DY
# 12            None              None                                  None
# 13    Diana White4    +49-30-1234500   Germany, Berlin, 12 Hauptstr, 10115
# 14   Edward Clark5   +91-98765-40010   India, Mumbai, 56 Marine Dr, 400001
# 15    Fiona6 Adams   +1-202-555-0456  USA, San Francisco, 34 Bay St, 94105
# 16  George7 Wilson  +44-20-7946-0567   UK, Manchester, 22 Queen St, M2 5PD
# 17    Helen8 Green              None                                  None
# 18            None    +49-30-9876500       USA, Austin, 89 River Rd, 73301
# 19    Jack Black10              None       USA, Seattle, 78 Pine St, 98101
# 20   Karen White11   +1-202-555-0789         USA, Boston, 10 Elm St, 02108
# 21    Liam Davis12  +44-20-7946-0890        USA, Miami, 88 Ocean Dr, 33139
# 22     Mia13 Evans   +1-202-555-0901      USA, Atlanta, 77 Peach St, 30303
# 23   Nathan14 King    +49-30-1357200       USA, Denver, 99 Rocky Rd, 80202
# 24  Olivia Scott15   +91-98765-60030      USA, Orlando, 66 Magic St, 32830
#
#     Order_ID  Order_Date  Order_Price  Factory_Cost   Tax  Shipping_Amount  \
# 0     1001.0  2023-06-15        200.0         120.0  20.0             15.0
# 1     1002.0  2023-07-21        110.0          80.0  10.5             12.0
# 2        NaN  2023-08-10          NaN           NaN   NaN              NaN
# 3     1004.0  2023-09-05         75.0          50.0   7.5             10.0
# 4     1005.0  2023-10-30        300.0         200.0  30.0             20.0
# 5     1006.0  2023-06-17        180.0         140.0  18.0             15.0
# 6        NaN  2023-11-11          NaN           NaN   NaN              NaN
# 7     1008.0        None        150.0         100.0  15.0             12.0
# 8     1009.0  2023-12-13        450.0         350.0  45.0             25.0
# 9     1010.0  2024-01-08        480.0         400.0  48.0             30.0
# 10    1001.0  2023-06-15        200.0         120.0  20.0             15.0
# 11    1002.0  2023-07-21        110.0          80.0  10.5             12.0
# 12       NaN        None          NaN           NaN   NaN              NaN
# 13    1004.0  2023-09-05         75.0          50.0   7.5             10.0
# 14    1005.0  2023-10-30        300.0         200.0  30.0             20.0
# 15    1006.0  2023-06-17        180.0         140.0  18.0             15.0
# 16       NaN  2023-11-11          NaN           NaN   NaN              NaN
# 17    1008.0        None        150.0         100.0  15.0             12.0
# 18       NaN  2023-12-13          NaN           NaN   NaN              NaN
# 19    1010.0  2024-01-08        480.0         400.0  48.0             30.0
# 20    1011.0  2024-02-20        175.0         130.0  17.5             14.0
# 21    1012.0  2024-03-22        250.0         190.0  25.0             18.0
# 22    1013.0  2024-04-30        135.0         100.0  13.5             11.0
# 23       NaN  2024-05-17          NaN           NaN   NaN              NaN
# 24    1015.0  2024-06-29        280.0         210.0  28.0             22.0
#
#    Shipping_Date    Payment_Method Customer_Type Order_Status  Discount_Amount
# 0     2023-06-18       Credit Card     Returning      Shipped             10.0
# 1     2023-07-23            PayPal           New      Pending              5.0
# 2     2023-08-12     Bank Transfer           New     Canceled              NaN
# 3     2023-09-08  Cash on Delivery     Returning    Delivered              0.0
# 4     2023-11-01       Credit Card           New      Shipped             15.0
# 5     2023-06-20            PayPal     Returning   Processing              8.0
# 6     2023-11-13     Bank Transfer           New    Delivered              NaN
# 7           None              None          None         None             12.0
# 8     2023-12-16       Credit Card     Returning      Shipped             20.0
# 9     2024-01-10        Debit Card           New      Pending             25.0
# 10    2023-06-18       Credit Card     Returning      Shipped             10.0
# 11    2023-07-23            PayPal           New      Pending              5.0
# 12          None              None          None         None              NaN
# 13    2023-09-08  Cash on Delivery     Returning    Delivered              0.0
# 14    2023-11-01       Credit Card           New      Shipped             15.0
# 15    2023-06-20            PayPal     Returning   Processing              8.0
# 16    2023-11-13     Bank Transfer           New    Delivered              NaN
# 17          None              None          None         None             12.0
# 18    2023-12-16       Credit Card     Returning      Shipped              NaN
# 19    2024-01-10        Debit Card           New      Pending             25.0
# 20    2024-02-23         Apple Pay           New     Canceled              7.0
# 21    2024-03-25        Google Pay     Returning    Delivered             10.0
# 22    2024-05-03    Cryptocurrency           New      Shipped              6.0
# 23    2024-05-20              None          None         None              NaN
# 24    2024-06-30       Credit Card     Returning   Processing             12.0

# %%
df.describe()
# Out:
#           Order_ID  Order_Price  Factory_Cost        Tax  Shipping_Amount  \
# count    19.000000    19.000000     19.000000  19.000000        19.000000
# mean   1006.947368   225.263158    166.315789  22.473684        16.736842
# std       4.182951   127.839675    107.971731  12.834928         6.252485
# min    1001.000000    75.000000     50.000000   7.500000        10.000000
# 25%    1004.000000   142.500000    100.000000  14.250000        12.000000
# 50%    1006.000000   180.000000    130.000000  18.000000        15.000000
# 75%    1010.000000   290.000000    200.000000  29.000000        20.000000
# max    1015.000000   480.000000    400.000000  48.000000        30.000000
#
#        Discount_Amount
# count        19.000000
# mean         10.789474
# std           7.004593
# min           0.000000
# 25%           6.500000
# 50%          10.000000
# 75%          13.500000
# max          25.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer         23 non-null     object
#  1   Phone_Number     22 non-null     object
#  2   Address          22 non-null     object
#  3   Order_ID         19 non-null     float64
#  4   Order_Date       22 non-null     object
#  5   Order_Price      19 non-null     float64
#  6   Factory_Cost     19 non-null     float64
#  7   Tax              19 non-null     float64
#  8   Shipping_Amount  19 non-null     float64
#  9   Shipping_Date    22 non-null     object
#  10  Payment_Method   21 non-null     object
#  11  Customer_Type    21 non-null     object
#  12  Order_Status     21 non-null     object
#  13  Discount_Amount  19 non-null     float64
# dtypes: float64(6), object(8)
# memory usage: 2.9+ KB

# %%
df.isnull().sum()
# Out:
# Customer           2
# Phone_Number       3
# Address            3
# Order_ID           6
# Order_Date         3
# Order_Price        6
# Factory_Cost       6
# Tax                6
# Shipping_Amount    6
# Shipping_Date      3
# Payment_Method     4
# Customer_Type      4
# Order_Status       4
# Discount_Amount    6
# dtype: int64

# %%
#Handeling nulls

# %%
df.fillna({'Customer': 'Unknown'}, inplace=True)
df.fillna({'Phone_Number':'0'}, inplace=True)
df.fillna({'Address':'unknown'}, inplace=True)

# %%
import numpy as np

# %%
df['Order_ID'] = df['Order_ID'].interpolate(method='linear')

# %%
df.fillna({'Order_Date':''}, inplace=True)
df.fillna({'Shipping_Date':''}, inplace=True)

# %%
df['Order_Price'].hist()
# Out:
# <Axes: >

# %%
df['Factory_Cost'].hist()
# Out:
# <Axes: >

# %%
df['Tax'].hist()
# Out:
# <Axes: >

# %%
df['Shipping_Amount'].hist()
# Out:
# <Axes: >

# %%
df['Order_Price'].fillna(df['Order_Price'].median(), inplace=True)
df['Factory_Cost'].fillna(df['Factory_Cost'].median(), inplace=True)
df['Tax'].fillna(df['Tax'].median(), inplace=True)
df['Shipping_Amount'].fillna(df['Shipping_Amount'].median(), inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16180\2875256514.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Order_Price'].fillna(df['Order_Price'].median(), inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16180\2875256514.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Factory_Cost'].fillna(df['Factory_Cost'].median(), inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16180\2875256514.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Tax'].fillna(df['Tax'].median(), inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16180\2875256514.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Shipping_Amount'].fillna(df['Shipping_Amount'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer           0
# Phone_Number       0
# Address            0
# Order_ID           0
# Order_Date         0
# Order_Price        0
# Factory_Cost       0
# Tax                0
# Shipping_Amount    0
# Shipping_Date      0
# Payment_Method     4
# Customer_Type      4
# Order_Status       4
# Discount_Amount    6
# dtype: int64

# %%
df
# Out:
#           Customer      Phone_Number                               Address  \
# 0   Alice Johnson1   +1-202-555-0101     USA, New York, 123 Main St, 10001
# 1       Bob2 Smith  +44-20-7946-0234       UK, London, 45 King St, W1B 4DY
# 2   Charlie3 Brown   +1-202-555-0345      USA, Chicago, 789 Oak Ave, 60611
# 3     Diana White4    +49-30-1234500   Germany, Berlin, 12 Hauptstr, 10115
# 4    Edward Clark5   +91-98765-40010   India, Mumbai, 56 Marine Dr, 400001
# 5     Fiona6 Adams   +1-202-555-0456  USA, San Francisco, 34 Bay St, 94105
# 6   George7 Wilson  +44-20-7946-0567   UK, Manchester, 22 Queen St, M2 5PD
# 7     Helen8 Green   +1-202-555-0678                               unknown
# 8      Ian Thomas9    +49-30-9876500       USA, Austin, 89 River Rd, 73301
# 9     Jack Black10   +91-98765-50021       USA, Seattle, 78 Pine St, 98101
# 10  Alice Johnson1   +1-202-555-0101     USA, New York, 123 Main St, 10001
# 11      Bob2 Smith  +44-20-7946-0234       UK, London, 45 King St, W1B 4DY
# 12         Unknown                 0                               unknown
# 13    Diana White4    +49-30-1234500   Germany, Berlin, 12 Hauptstr, 10115
# 14   Edward Clark5   +91-98765-40010   India, Mumbai, 56 Marine Dr, 400001
# 15    Fiona6 Adams   +1-202-555-0456  USA, San Francisco, 34 Bay St, 94105
# 16  George7 Wilson  +44-20-7946-0567   UK, Manchester, 22 Queen St, M2 5PD
# 17    Helen8 Green                 0                               unknown
# 18         Unknown    +49-30-9876500       USA, Austin, 89 River Rd, 73301
# 19    Jack Black10                 0       USA, Seattle, 78 Pine St, 98101
# 20   Karen White11   +1-202-555-0789         USA, Boston, 10 Elm St, 02108
# 21    Liam Davis12  +44-20-7946-0890        USA, Miami, 88 Ocean Dr, 33139
# 22     Mia13 Evans   +1-202-555-0901      USA, Atlanta, 77 Peach St, 30303
# 23   Nathan14 King    +49-30-1357200       USA, Denver, 99 Rocky Rd, 80202
# 24  Olivia Scott15   +91-98765-60030      USA, Orlando, 66 Magic St, 32830
#
#     Order_ID  Order_Date  Order_Price  Factory_Cost   Tax  Shipping_Amount  \
# 0     1001.0  2023-06-15        200.0         120.0  20.0             15.0
# 1     1002.0  2023-07-21        110.0          80.0  10.5             12.0
# 2     1003.0  2023-08-10        180.0         130.0  18.0             15.0
# 3     1004.0  2023-09-05         75.0          50.0   7.5             10.0
# 4     1005.0  2023-10-30        300.0         200.0  30.0             20.0
# 5     1006.0  2023-06-17        180.0         140.0  18.0             15.0
# 6     1007.0  2023-11-11        180.0         130.0  18.0             15.0
# 7     1008.0                    150.0         100.0  15.0             12.0
# 8     1009.0  2023-12-13        450.0         350.0  45.0             25.0
# 9     1010.0  2024-01-08        480.0         400.0  48.0             30.0
# 10    1001.0  2023-06-15        200.0         120.0  20.0             15.0
# 11    1002.0  2023-07-21        110.0          80.0  10.5             12.0
# 12    1003.0                    180.0         130.0  18.0             15.0
# 13    1004.0  2023-09-05         75.0          50.0   7.5             10.0
# 14    1005.0  2023-10-30        300.0         200.0  30.0             20.0
# 15    1006.0  2023-06-17        180.0         140.0  18.0             15.0
# 16    1007.0  2023-11-11        180.0         130.0  18.0             15.0
# 17    1008.0                    150.0         100.0  15.0             12.0
# 18    1009.0  2023-12-13        180.0         130.0  18.0             15.0
# 19    1010.0  2024-01-08        480.0         400.0  48.0             30.0
# 20    1011.0  2024-02-20        175.0         130.0  17.5             14.0
# 21    1012.0  2024-03-22        250.0         190.0  25.0             18.0
# 22    1013.0  2024-04-30        135.0         100.0  13.5             11.0
# 23    1014.0  2024-05-17        180.0         130.0  18.0             15.0
# 24    1015.0  2024-06-29        280.0         210.0  28.0             22.0
#
#    Shipping_Date    Payment_Method Customer_Type Order_Status  Discount_Amount
# 0     2023-06-18       Credit Card     Returning      Shipped             10.0
# 1     2023-07-23            PayPal           New      Pending              5.0
# 2     2023-08-12     Bank Transfer           New     Canceled              NaN
# 3     2023-09-08  Cash on Delivery     Returning    Delivered              0.0
# 4     2023-11-01       Credit Card           New      Shipped             15.0
# 5     2023-06-20            PayPal     Returning   Processing              8.0
# 6     2023-11-13     Bank Transfer           New    Delivered              NaN
# 7                             None          None         None             12.0
# 8     2023-12-16       Credit Card     Returning      Shipped             20.0
# 9     2024-01-10        Debit Card           New      Pending             25.0
# 10    2023-06-18       Credit Card     Returning      Shipped             10.0
# 11    2023-07-23            PayPal           New      Pending              5.0
# 12                            None          None         None              NaN
# 13    2023-09-08  Cash on Delivery     Returning    Delivered              0.0
# 14    2023-11-01       Credit Card           New      Shipped             15.0
# 15    2023-06-20            PayPal     Returning   Processing              8.0
# 16    2023-11-13     Bank Transfer           New    Delivered              NaN
# 17                            None          None         None             12.0
# 18    2023-12-16       Credit Card     Returning      Shipped              NaN
# 19    2024-01-10        Debit Card           New      Pending             25.0
# 20    2024-02-23         Apple Pay           New     Canceled              7.0
# 21    2024-03-25        Google Pay     Returning    Delivered             10.0
# 22    2024-05-03    Cryptocurrency           New      Shipped              6.0
# 23    2024-05-20              None          None         None              NaN
# 24    2024-06-30       Credit Card     Returning   Processing             12.0

# %%
df.fillna({'Customer_Type':'unknown'}, inplace=True)
df.fillna({'Address':'unknown'}, inplace=True)
df.fillna({'Order_Status':'unknown'}, inplace=True)

# %%
df['Discount_Amount'].hist()
# Out:
# <Axes: >

# %%
df['Discount_Amount'].fillna(df['Discount_Amount'].mean(), inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16180\2413366488.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Discount_Amount'].fillna(df['Discount_Amount'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer           0
# Phone_Number       0
# Address            0
# Order_ID           0
# Order_Date         0
# Order_Price        0
# Factory_Cost       0
# Tax                0
# Shipping_Amount    0
# Shipping_Date      0
# Payment_Method     4
# Customer_Type      0
# Order_Status       0
# Discount_Amount    0
# dtype: int64

# %%
df.fillna({'Payment_Method':'unknown'}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer           0
# Phone_Number       0
# Address            0
# Order_ID           0
# Order_Date         0
# Order_Price        0
# Factory_Cost       0
# Tax                0
# Shipping_Amount    0
# Shipping_Date      0
# Payment_Method     0
# Customer_Type      0
# Order_Status       0
# Discount_Amount    0
# dtype: int64

# %%
df
# Out:
#           Customer      Phone_Number                               Address  \
# 0   Alice Johnson1   +1-202-555-0101     USA, New York, 123 Main St, 10001
# 1       Bob2 Smith  +44-20-7946-0234       UK, London, 45 King St, W1B 4DY
# 2   Charlie3 Brown   +1-202-555-0345      USA, Chicago, 789 Oak Ave, 60611
# 3     Diana White4    +49-30-1234500   Germany, Berlin, 12 Hauptstr, 10115
# 4    Edward Clark5   +91-98765-40010   India, Mumbai, 56 Marine Dr, 400001
# 5     Fiona6 Adams   +1-202-555-0456  USA, San Francisco, 34 Bay St, 94105
# 6   George7 Wilson  +44-20-7946-0567   UK, Manchester, 22 Queen St, M2 5PD
# 7     Helen8 Green   +1-202-555-0678                               unknown
# 8      Ian Thomas9    +49-30-9876500       USA, Austin, 89 River Rd, 73301
# 9     Jack Black10   +91-98765-50021       USA, Seattle, 78 Pine St, 98101
# 10  Alice Johnson1   +1-202-555-0101     USA, New York, 123 Main St, 10001
# 11      Bob2 Smith  +44-20-7946-0234       UK, London, 45 King St, W1B 4DY
# 12         Unknown                 0                               unknown
# 13    Diana White4    +49-30-1234500   Germany, Berlin, 12 Hauptstr, 10115
# 14   Edward Clark5   +91-98765-40010   India, Mumbai, 56 Marine Dr, 400001
# 15    Fiona6 Adams   +1-202-555-0456  USA, San Francisco, 34 Bay St, 94105
# 16  George7 Wilson  +44-20-7946-0567   UK, Manchester, 22 Queen St, M2 5PD
# 17    Helen8 Green                 0                               unknown
# 18         Unknown    +49-30-9876500       USA, Austin, 89 River Rd, 73301
# 19    Jack Black10                 0       USA, Seattle, 78 Pine St, 98101
# 20   Karen White11   +1-202-555-0789         USA, Boston, 10 Elm St, 02108
# 21    Liam Davis12  +44-20-7946-0890        USA, Miami, 88 Ocean Dr, 33139
# 22     Mia13 Evans   +1-202-555-0901      USA, Atlanta, 77 Peach St, 30303
# 23   Nathan14 King    +49-30-1357200       USA, Denver, 99 Rocky Rd, 80202
# 24  Olivia Scott15   +91-98765-60030      USA, Orlando, 66 Magic St, 32830
#
#     Order_ID  Order_Date  Order_Price  Factory_Cost   Tax  Shipping_Amount  \
# 0     1001.0  2023-06-15        200.0         120.0  20.0             15.0
# 1     1002.0  2023-07-21        110.0          80.0  10.5             12.0
# 2     1003.0  2023-08-10        180.0         130.0  18.0             15.0
# 3     1004.0  2023-09-05         75.0          50.0   7.5             10.0
# 4     1005.0  2023-10-30        300.0         200.0  30.0             20.0
# 5     1006.0  2023-06-17        180.0         140.0  18.0             15.0
# 6     1007.0  2023-11-11        180.0         130.0  18.0             15.0
# 7     1008.0                    150.0         100.0  15.0             12.0
# 8     1009.0  2023-12-13        450.0         350.0  45.0             25.0
# 9     1010.0  2024-01-08        480.0         400.0  48.0             30.0
# 10    1001.0  2023-06-15        200.0         120.0  20.0             15.0
# 11    1002.0  2023-07-21        110.0          80.0  10.5             12.0
# 12    1003.0                    180.0         130.0  18.0             15.0
# 13    1004.0  2023-09-05         75.0          50.0   7.5             10.0
# 14    1005.0  2023-10-30        300.0         200.0  30.0             20.0
# 15    1006.0  2023-06-17        180.0         140.0  18.0             15.0
# 16    1007.0  2023-11-11        180.0         130.0  18.0             15.0
# 17    1008.0                    150.0         100.0  15.0             12.0
# 18    1009.0  2023-12-13        180.0         130.0  18.0             15.0
# 19    1010.0  2024-01-08        480.0         400.0  48.0             30.0
# 20    1011.0  2024-02-20        175.0         130.0  17.5             14.0
# 21    1012.0  2024-03-22        250.0         190.0  25.0             18.0
# 22    1013.0  2024-04-30        135.0         100.0  13.5             11.0
# 23    1014.0  2024-05-17        180.0         130.0  18.0             15.0
# 24    1015.0  2024-06-29        280.0         210.0  28.0             22.0
#
#    Shipping_Date    Payment_Method Customer_Type Order_Status  Discount_Amount
# 0     2023-06-18       Credit Card     Returning      Shipped        10.000000
# 1     2023-07-23            PayPal           New      Pending         5.000000
# 2     2023-08-12     Bank Transfer           New     Canceled        10.789474
# 3     2023-09-08  Cash on Delivery     Returning    Delivered         0.000000
# 4     2023-11-01       Credit Card           New      Shipped        15.000000
# 5     2023-06-20            PayPal     Returning   Processing         8.000000
# 6     2023-11-13     Bank Transfer           New    Delivered        10.789474
# 7                          unknown       unknown      unknown        12.000000
# 8     2023-12-16       Credit Card     Returning      Shipped        20.000000
# 9     2024-01-10        Debit Card           New      Pending        25.000000
# 10    2023-06-18       Credit Card     Returning      Shipped        10.000000
# 11    2023-07-23            PayPal           New      Pending         5.000000
# 12                         unknown       unknown      unknown        10.789474
# 13    2023-09-08  Cash on Delivery     Returning    Delivered         0.000000
# 14    2023-11-01       Credit Card           New      Shipped        15.000000
# 15    2023-06-20            PayPal     Returning   Processing         8.000000
# 16    2023-11-13     Bank Transfer           New    Delivered        10.789474
# 17                         unknown       unknown      unknown        12.000000
# 18    2023-12-16       Credit Card     Returning      Shipped        10.789474
# 19    2024-01-10        Debit Card           New      Pending        25.000000
# 20    2024-02-23         Apple Pay           New     Canceled         7.000000
# 21    2024-03-25        Google Pay     Returning    Delivered        10.000000
# 22    2024-05-03    Cryptocurrency           New      Shipped         6.000000
# 23    2024-05-20           unknown       unknown      unknown        10.789474
# 24    2024-06-30       Credit Card     Returning   Processing        12.000000

# %%
df[["city_code","actual_number"]]=df["Phone_Number"].str.split("-",n=1, expand=True)

# %%
df
# Out:
#           Customer      Phone_Number                               Address  \
# 0   Alice Johnson1   +1-202-555-0101     USA, New York, 123 Main St, 10001
# 1       Bob2 Smith  +44-20-7946-0234       UK, London, 45 King St, W1B 4DY
# 2   Charlie3 Brown   +1-202-555-0345      USA, Chicago, 789 Oak Ave, 60611
# 3     Diana White4    +49-30-1234500   Germany, Berlin, 12 Hauptstr, 10115
# 4    Edward Clark5   +91-98765-40010   India, Mumbai, 56 Marine Dr, 400001
# 5     Fiona6 Adams   +1-202-555-0456  USA, San Francisco, 34 Bay St, 94105
# 6   George7 Wilson  +44-20-7946-0567   UK, Manchester, 22 Queen St, M2 5PD
# 7     Helen8 Green   +1-202-555-0678                               unknown
# 8      Ian Thomas9    +49-30-9876500       USA, Austin, 89 River Rd, 73301
# 9     Jack Black10   +91-98765-50021       USA, Seattle, 78 Pine St, 98101
# 10  Alice Johnson1   +1-202-555-0101     USA, New York, 123 Main St, 10001
# 11      Bob2 Smith  +44-20-7946-0234       UK, London, 45 King St, W1B 4DY
# 12         Unknown                 0                               unknown
# 13    Diana White4    +49-30-1234500   Germany, Berlin, 12 Hauptstr, 10115
# 14   Edward Clark5   +91-98765-40010   India, Mumbai, 56 Marine Dr, 400001
# 15    Fiona6 Adams   +1-202-555-0456  USA, San Francisco, 34 Bay St, 94105
# 16  George7 Wilson  +44-20-7946-0567   UK, Manchester, 22 Queen St, M2 5PD
# 17    Helen8 Green                 0                               unknown
# 18         Unknown    +49-30-9876500       USA, Austin, 89 River Rd, 73301
# 19    Jack Black10                 0       USA, Seattle, 78 Pine St, 98101
# 20   Karen White11   +1-202-555-0789         USA, Boston, 10 Elm St, 02108
# 21    Liam Davis12  +44-20-7946-0890        USA, Miami, 88 Ocean Dr, 33139
# 22     Mia13 Evans   +1-202-555-0901      USA, Atlanta, 77 Peach St, 30303
# 23   Nathan14 King    +49-30-1357200       USA, Denver, 99 Rocky Rd, 80202
# 24  Olivia Scott15   +91-98765-60030      USA, Orlando, 66 Magic St, 32830
#
#     Order_ID  Order_Date  Order_Price  Factory_Cost   Tax  Shipping_Amount  \
# 0     1001.0  2023-06-15        200.0         120.0  20.0             15.0
# 1     1002.0  2023-07-21        110.0          80.0  10.5             12.0
# 2     1003.0  2023-08-10        180.0         130.0  18.0             15.0
# 3     1004.0  2023-09-05         75.0          50.0   7.5             10.0
# 4     1005.0  2023-10-30        300.0         200.0  30.0             20.0
# 5     1006.0  2023-06-17        180.0         140.0  18.0             15.0
# 6     1007.0  2023-11-11        180.0         130.0  18.0             15.0
# 7     1008.0                    150.0         100.0  15.0             12.0
# 8     1009.0  2023-12-13        450.0         350.0  45.0             25.0
# 9     1010.0  2024-01-08        480.0         400.0  48.0             30.0
# 10    1001.0  2023-06-15        200.0         120.0  20.0             15.0
# 11    1002.0  2023-07-21        110.0          80.0  10.5             12.0
# 12    1003.0                    180.0         130.0  18.0             15.0
# 13    1004.0  2023-09-05         75.0          50.0   7.5             10.0
# 14    1005.0  2023-10-30        300.0         200.0  30.0             20.0
# 15    1006.0  2023-06-17        180.0         140.0  18.0             15.0
# 16    1007.0  2023-11-11        180.0         130.0  18.0             15.0
# 17    1008.0                    150.0         100.0  15.0             12.0
# 18    1009.0  2023-12-13        180.0         130.0  18.0             15.0
# 19    1010.0  2024-01-08        480.0         400.0  48.0             30.0
# 20    1011.0  2024-02-20        175.0         130.0  17.5             14.0
# 21    1012.0  2024-03-22        250.0         190.0  25.0             18.0
# 22    1013.0  2024-04-30        135.0         100.0  13.5             11.0
# 23    1014.0  2024-05-17        180.0         130.0  18.0             15.0
# 24    1015.0  2024-06-29        280.0         210.0  28.0             22.0
#
#    Shipping_Date    Payment_Method Customer_Type Order_Status  \
# 0     2023-06-18       Credit Card     Returning      Shipped
# 1     2023-07-23            PayPal           New      Pending
# 2     2023-08-12     Bank Transfer           New     Canceled
# 3     2023-09-08  Cash on Delivery     Returning    Delivered
# 4     2023-11-01       Credit Card           New      Shipped
# 5     2023-06-20            PayPal     Returning   Processing
# 6     2023-11-13     Bank Transfer           New    Delivered
# 7                          unknown       unknown      unknown
# 8     2023-12-16       Credit Card     Returning      Shipped
# 9     2024-01-10        Debit Card           New      Pending
# 10    2023-06-18       Credit Card     Returning      Shipped
# 11    2023-07-23            PayPal           New      Pending
# 12                         unknown       unknown      unknown
# 13    2023-09-08  Cash on Delivery     Returning    Delivered
# 14    2023-11-01       Credit Card           New      Shipped
# 15    2023-06-20            PayPal     Returning   Processing
# 16    2023-11-13     Bank Transfer           New    Delivered
# 17                         unknown       unknown      unknown
# 18    2023-12-16       Credit Card     Returning      Shipped
# 19    2024-01-10        Debit Card           New      Pending
# 20    2024-02-23         Apple Pay           New     Canceled
# 21    2024-03-25        Google Pay     Returning    Delivered
# 22    2024-05-03    Cryptocurrency           New      Shipped
# 23    2024-05-20           unknown       unknown      unknown
# 24    2024-06-30       Credit Card     Returning   Processing
#
#     Discount_Amount city_code actual_number
# 0         10.000000        +1  202-555-0101
# 1          5.000000       +44  20-7946-0234
# 2         10.789474        +1  202-555-0345
# 3          0.000000       +49    30-1234500
# 4         15.000000       +91   98765-40010
# 5          8.000000        +1  202-555-0456
# 6         10.789474       +44  20-7946-0567
# 7         12.000000        +1  202-555-0678
# 8         20.000000       +49    30-9876500
# 9         25.000000       +91   98765-50021
# 10        10.000000        +1  202-555-0101
# 11         5.000000       +44  20-7946-0234
# 12        10.789474         0          None
# 13         0.000000       +49    30-1234500
# 14        15.000000       +91   98765-40010
# 15         8.000000        +1  202-555-0456
# 16        10.789474       +44  20-7946-0567
# 17        12.000000         0          None
# 18        10.789474       +49    30-9876500
# 19        25.000000         0          None
# 20         7.000000        +1  202-555-0789
# 21        10.000000       +44  20-7946-0890
# 22         6.000000        +1  202-555-0901
# 23        10.789474       +49    30-1357200
# 24        12.000000       +91   98765-60030

# %%
df.drop(columns=["Phone_Number"],inplace=True)

# %%
df[["country","city","street","postal_code"]]=df["Address"].str.split(",",n=3, expand=True)

# %%
df.drop(columns=["Address"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer         25 non-null     object
#  1   Order_ID         25 non-null     float64
#  2   Order_Date       25 non-null     object
#  3   Order_Price      25 non-null     float64
#  4   Factory_Cost     25 non-null     float64
#  5   Tax              25 non-null     float64
#  6   Shipping_Amount  25 non-null     float64
#  7   Shipping_Date    25 non-null     object
#  8   Payment_Method   25 non-null     object
#  9   Customer_Type    25 non-null     object
#  10  Order_Status     25 non-null     object
#  11  Discount_Amount  25 non-null     float64
#  12  city_code        25 non-null     object
#  13  actual_number    22 non-null     object
#  14  country          25 non-null     object
#  15  city             22 non-null     object
#  16  street           22 non-null     object
#  17  postal_code      22 non-null     object
# dtypes: float64(6), object(12)
# memory usage: 3.6+ KB

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Shipping_Date'] = pd.to_datetime(df['Shipping_Date'])

# %%
df['shipping_time'] =  df['Shipping_Date']-df['Order_Date']

# %%
df.describe()
# Out:
#           Order_ID           Order_Date  Order_Price  Factory_Cost       Tax  \
# count    25.000000                   22    25.000000     25.000000  25.00000
# mean   1007.000000  2023-11-08 00:00:00   214.400000    157.600000  21.40000
# min    1001.000000  2023-06-15 00:00:00    75.000000     50.000000   7.50000
# 25%    1004.000000  2023-07-26 00:00:00   150.000000    100.000000  15.00000
# 50%    1007.000000  2023-11-05 00:00:00   180.000000    130.000000  18.00000
# 75%    1010.000000  2024-01-08 00:00:00   250.000000    190.000000  25.00000
# max    1015.000000  2024-06-29 00:00:00   480.000000    400.000000  48.00000
# std       4.082483                  NaN   112.456658     94.836702  11.28513
#
#        Shipping_Amount        Shipping_Date  Discount_Amount  \
# count         25.00000                   22        25.000000
# mean          16.32000  2023-11-10 12:00:00        10.789474
# min           10.00000  2023-06-18 00:00:00         0.000000
# 25%           12.00000  2023-07-28 00:00:00         8.000000
# 50%           15.00000  2023-11-07 00:00:00        10.789474
# 75%           18.00000  2024-01-10 00:00:00        12.000000
# max           30.00000  2024-06-30 00:00:00        25.000000
# std            5.46748                  NaN         6.066156
#
#                    shipping_time
# count                         22
# mean             2 days 12:00:00
# min              1 days 00:00:00
# 25%              2 days 00:00:00
# 50%              3 days 00:00:00
# 75%              3 days 00:00:00
# max              3 days 00:00:00
# std    0 days 14:20:33.875923245

# %%
df.isnull().sum()
# Out:
# Customer           0
# Order_ID           0
# Order_Date         3
# Order_Price        0
# Factory_Cost       0
# Tax                0
# Shipping_Amount    0
# Shipping_Date      3
# Payment_Method     0
# Customer_Type      0
# Order_Status       0
# Discount_Amount    0
# city_code          0
# actual_number      3
# country            0
# city               3
# street             3
# postal_code        3
# shipping_time      3
# dtype: int64

# %%
df.fillna({'Order_Date':'0'}, inplace=True)
df.fillna({'Shipping_Date':'0'}, inplace=True)
df.fillna({'actual_number':''}, inplace=True)
df.fillna({'city':'unknown'}, inplace=True)
df.fillna({'street':'unknown'}, inplace=True)
df.fillna({'postal_code':''}, inplace=True)
df.fillna({'shipping_time':'0'}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer           0
# Order_ID           0
# Order_Date         0
# Order_Price        0
# Factory_Cost       0
# Tax                0
# Shipping_Amount    0
# Shipping_Date      0
# Payment_Method     0
# Customer_Type      0
# Order_Status       0
# Discount_Amount    0
# city_code          0
# actual_number      0
# country            0
# city               0
# street             0
# postal_code        0
# shipping_time      0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#           Customer  Order_ID           Order_Date  Order_Price  Factory_Cost  \
# 0   Alice Johnson1    1001.0  2023-06-15 00:00:00        200.0         120.0
# 1       Bob2 Smith    1002.0  2023-07-21 00:00:00        110.0          80.0
# 2   Charlie3 Brown    1003.0  2023-08-10 00:00:00        180.0         130.0
# 3     Diana White4    1004.0  2023-09-05 00:00:00         75.0          50.0
# 4    Edward Clark5    1005.0  2023-10-30 00:00:00        300.0         200.0
# 5     Fiona6 Adams    1006.0  2023-06-17 00:00:00        180.0         140.0
# 6   George7 Wilson    1007.0  2023-11-11 00:00:00        180.0         130.0
# 7     Helen8 Green    1008.0                    0        150.0         100.0
# 8      Ian Thomas9    1009.0  2023-12-13 00:00:00        450.0         350.0
# 9     Jack Black10    1010.0  2024-01-08 00:00:00        480.0         400.0
# 10  Alice Johnson1    1001.0  2023-06-15 00:00:00        200.0         120.0
# 11      Bob2 Smith    1002.0  2023-07-21 00:00:00        110.0          80.0
# 12         Unknown    1003.0                    0        180.0         130.0
# 13    Diana White4    1004.0  2023-09-05 00:00:00         75.0          50.0
# 14   Edward Clark5    1005.0  2023-10-30 00:00:00        300.0         200.0
# 15    Fiona6 Adams    1006.0  2023-06-17 00:00:00        180.0         140.0
# 16  George7 Wilson    1007.0  2023-11-11 00:00:00        180.0         130.0
# 17    Helen8 Green    1008.0                    0        150.0         100.0
# 18         Unknown    1009.0  2023-12-13 00:00:00        180.0         130.0
# 19    Jack Black10    1010.0  2024-01-08 00:00:00        480.0         400.0
# 20   Karen White11    1011.0  2024-02-20 00:00:00        175.0         130.0
# 21    Liam Davis12    1012.0  2024-03-22 00:00:00        250.0         190.0
# 22     Mia13 Evans    1013.0  2024-04-30 00:00:00        135.0         100.0
# 23   Nathan14 King    1014.0  2024-05-17 00:00:00        180.0         130.0
# 24  Olivia Scott15    1015.0  2024-06-29 00:00:00        280.0         210.0
#
#      Tax  Shipping_Amount        Shipping_Date    Payment_Method  \
# 0   20.0             15.0  2023-06-18 00:00:00       Credit Card
# 1   10.5             12.0  2023-07-23 00:00:00            PayPal
# 2   18.0             15.0  2023-08-12 00:00:00     Bank Transfer
# 3    7.5             10.0  2023-09-08 00:00:00  Cash on Delivery
# 4   30.0             20.0  2023-11-01 00:00:00       Credit Card
# 5   18.0             15.0  2023-06-20 00:00:00            PayPal
# 6   18.0             15.0  2023-11-13 00:00:00     Bank Transfer
# 7   15.0             12.0                    0           unknown
# 8   45.0             25.0  2023-12-16 00:00:00       Credit Card
# 9   48.0             30.0  2024-01-10 00:00:00        Debit Card
# 10  20.0             15.0  2023-06-18 00:00:00       Credit Card
# 11  10.5             12.0  2023-07-23 00:00:00            PayPal
# 12  18.0             15.0                    0           unknown
# 13   7.5             10.0  2023-09-08 00:00:00  Cash on Delivery
# 14  30.0             20.0  2023-11-01 00:00:00       Credit Card
# 15  18.0             15.0  2023-06-20 00:00:00            PayPal
# 16  18.0             15.0  2023-11-13 00:00:00     Bank Transfer
# 17  15.0             12.0                    0           unknown
# 18  18.0             15.0  2023-12-16 00:00:00       Credit Card
# 19  48.0             30.0  2024-01-10 00:00:00        Debit Card
# 20  17.5             14.0  2024-02-23 00:00:00         Apple Pay
# 21  25.0             18.0  2024-03-25 00:00:00        Google Pay
# 22  13.5             11.0  2024-05-03 00:00:00    Cryptocurrency
# 23  18.0             15.0  2024-05-20 00:00:00           unknown
# 24  28.0             22.0  2024-06-30 00:00:00       Credit Card
#
#    Customer_Type Order_Status  Discount_Amount city_code actual_number  \
# 0      Returning      Shipped        10.000000        +1  202-555-0101
# 1            New      Pending         5.000000       +44  20-7946-0234
# 2            New     Canceled        10.789474        +1  202-555-0345
# 3      Returning    Delivered         0.000000       +49    30-1234500
# 4            New      Shipped        15.000000       +91   98765-40010
# 5      Returning   Processing         8.000000        +1  202-555-0456
# 6            New    Delivered        10.789474       +44  20-7946-0567
# 7        unknown      unknown        12.000000        +1  202-555-0678
# 8      Returning      Shipped        20.000000       +49    30-9876500
# 9            New      Pending        25.000000       +91   98765-50021
# 10     Returning      Shipped        10.000000        +1  202-555-0101
# 11           New      Pending         5.000000       +44  20-7946-0234
# 12       unknown      unknown        10.789474         0
# 13     Returning    Delivered         0.000000       +49    30-1234500
# 14           New      Shipped        15.000000       +91   98765-40010
# 15     Returning   Processing         8.000000        +1  202-555-0456
# 16           New    Delivered        10.789474       +44  20-7946-0567
# 17       unknown      unknown        12.000000         0
# 18     Returning      Shipped        10.789474       +49    30-9876500
# 19           New      Pending        25.000000         0
# 20           New     Canceled         7.000000        +1  202-555-0789
# 21     Returning    Delivered        10.000000       +44  20-7946-0890
# 22           New      Shipped         6.000000        +1  202-555-0901
# 23       unknown      unknown        10.789474       +49    30-1357200
# 24     Returning   Processing        12.000000       +91   98765-60030
#
#     country            city         street postal_code shipping_time
# 0       USA        New York    123 Main St       10001        3 days
# 1        UK          London     45 King St     W1B 4DY        2 days
# 2       USA         Chicago    789 Oak Ave       60611        2 days
# 3   Germany          Berlin    12 Hauptstr       10115        3 days
# 4     India          Mumbai   56 Marine Dr      400001        2 days
# 5       USA   San Francisco      34 Bay St       94105        3 days
# 6        UK      Manchester    22 Queen St      M2 5PD        2 days
# 7   unknown         unknown        unknown                    0 days
# 8       USA          Austin    89 River Rd       73301        3 days
# 9       USA         Seattle     78 Pine St       98101        2 days
# 10      USA        New York    123 Main St       10001        3 days
# 11       UK          London     45 King St     W1B 4DY        2 days
# 12  unknown         unknown        unknown                    0 days
# 13  Germany          Berlin    12 Hauptstr       10115        3 days
# 14    India          Mumbai   56 Marine Dr      400001        2 days
# 15      USA   San Francisco      34 Bay St       94105        3 days
# 16       UK      Manchester    22 Queen St      M2 5PD        2 days
# 17  unknown         unknown        unknown                    0 days
# 18      USA          Austin    89 River Rd       73301        3 days
# 19      USA         Seattle     78 Pine St       98101        2 days
# 20      USA          Boston      10 Elm St       02108        3 days
# 21      USA           Miami    88 Ocean Dr       33139        3 days
# 22      USA         Atlanta    77 Peach St       30303        3 days
# 23      USA          Denver    99 Rocky Rd       80202        3 days
# 24      USA         Orlando    66 Magic St       32830        1 days

# %%
df['shipping_time'] = pd.to_numeric(df['shipping_time'])

# %%
df[['country', 'shipping_time']].plot(kind='line', x='country', y='shipping_time')
# Out:
# <Axes: xlabel='country'>

# %%
status_counts = df['Order_Status'].value_counts()

# %%
status_counts.plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
Payment_Method_counts=df['Payment_Method'].value_counts()
Payment_Method_counts.plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
Customer_Type_counts = df['Customer_Type'].value_counts()
Customer_Type_counts.plot(kind='bar',x='Customer_Type',y='Customer_Type_counts',color='red')
# Out:
# <Axes: xlabel='Customer_Type'>

# %%
orders_counts = df['country'].value_counts()
orders_counts.plot(kind='bar',x='country',y='orders_counts',color='yellow')
# Out:
# <Axes: xlabel='country'>

# %%
print(df.columns)
# Out:
# Index(['Customer', 'Order_ID', 'Order_Date', 'Order_Price', 'Factory_Cost',
#        'Tax', 'Shipping_Amount', 'Shipping_Date', 'Payment_Method',
#        'Customer_Type', 'Order_Status', 'Discount_Amount', 'city_code',
#        'actual_number', 'country', 'city', 'street', 'postal_code',
#        'shipping_time'],
#       dtype='object')

# %%
total_cost_per_country=df.groupby('country')['Factory_Cost'].sum()

# %%
print(total_cost_per_country)
# Out:
# country
# Germany     100.0
# India       400.0
# UK          420.0
# USA        2690.0
# unknown     330.0
# Name: Factory_Cost, dtype: float64

# %%
total_cost_per_country.plot(kind='bar',color='green')
# Out:
# <Axes: xlabel='country'>

# %%
df['Order_Price'] = pd.to_numeric(df['Order_Price'])
df['Tax'] = pd.to_numeric(df['Tax'])

# %%
df['profit']=df['Order_Price']-df['Tax']-df['Factory_Cost']

# %%
df[['profit','Order_Price']].plot(kind='bar',x='Order_Price',y='profit',color='purple')
# Out:
# <Axes: xlabel='Order_Price'>
